# %%
import pandas as pd
import numpy as np
import requests

np.random.seed(42)

# %%
keywords = ["Aloe vera juice", "Fruit drink", "Curcumin C3", "Graviola", "Ecoensulin"]

rows_per_keyword = 400  # 5 keywords × 400 = 2000 rows
dates = pd.date_range(end=pd.Timestamp.today(), periods=rows_per_keyword)

# %%
rows = []

for keyword in keywords:
    base_impressions = np.random.randint(1000, 5000)
    inventory = np.random.randint(50,150)

    for i in range(rows_per_keyword):
        trend = 1 + (i * 0.001)
        impressions = int(base_impressions * trend * np.random.uniform(0.9,1.1))
        ctr = np.random.uniform(0.02, 0.08)
        clicks = int(impressions * ctr)
        cpc = np.random.uniform(5,15)
        spend = clicks * cpc
        cvr = np.random.uniform(0.1,0.3)
        orders = int(clicks * cvr)
        avg_order_value = np.random.uniform(300,800)
        sales = orders * avg_order_value
        bid = cpc * np.random.uniform(0.9,1.2)
        acos = spend / sales if sales>0 else 0
        roas = sales / spend if spend>0 else 0
        inventory -= orders
        stock_out_flag = 1 if inventory <= 0 else 0
        inventory = max(inventory,0)
        organic_rank = np.random.randint(1,100)

        rows.append([
            dates[i], keyword, impressions, clicks, spend, sales,
            orders, ctr, cpc, cvr, acos, roas, bid,
            inventory, stock_out_flag, organic_rank
        ])

# %%
df = pd.DataFrame(rows, columns=[
    "date","keyword","impressions","clicks","spend","sales",
    "orders","ctr","cpc","cvr","acos","roas","bid",
    "inventory_level","stock_out_flag","organic_rank"
])

# %%
df = df.sort_values(by=["keyword","date"])

for col in ["impressions","clicks","spend","sales","orders","ctr","cvr","acos","cpc"]:
    df[f"{col}_change_1d"] = df.groupby("keyword")[col].pct_change()

df = df.fillna(0)

# %%
df = df.sort_values(by=["keyword","date"])

for col in ["impressions","clicks","spend","sales","orders","ctr","cvr","acos","cpc"]:
    df[f"{col}_change_1d"] = df.groupby("keyword")[col].pct_change()

df = df.fillna(0)

# %%
API_KEY = "41CCD23CF84449F6B7F0CA75B4D1DC1B"

# %%
def fetch_rainforest_data(keyword):
    url = "https://api.rainforestapi.com/request"
    params = {
        "api_key": API_KEY,
        "type": "search",
        "amazon_domain": "amazon.in",
        "search_term": keyword
    }
    try:
        response = requests.get(url, params=params)
        data = response.json()
        
        # Rainforest API ka actual path 'search_results' list hota hai
        all_results = data.get("search_results", [])
        
        sponsored_count = 0
        organic_count = 0
        prices = []
        ratings = []

        for item in all_results:
            # Check if item is sponsored
            if item.get("sponsored", False):
                sponsored_count += 1
            else:
                organic_count += 1
                # Organic products ka price aur rating lena
                if "price" in item and "value" in item["price"]:
                    prices.append(item["price"]["value"])
                if "rating" in item:
                    ratings.append(item["rating"])

        avg_price = np.mean(prices) if prices else 0
        avg_rating = np.mean(ratings) if ratings else 0
        
        return {
            "competitor_avg_price": avg_price,
            "sponsored_count": sponsored_count,
            "organic_count": organic_count,
            "competitor_avg_rating": avg_rating
        }
    except Exception as e:
        print(f"Error fetching {keyword}: {e}")
        return {
            "competitor_avg_price": 0, "sponsored_count": 0,
            "organic_count": 0, "competitor_avg_rating": 0
        }

# %%
market_data = {}

for kw in keywords:
    print(f"Fetching competitor data for {kw}...")
    market_data[kw] = fetch_rainforest_data(kw)
# Out:
# Fetching competitor data for Aloe vera juice...
# Fetching competitor data for Fruit drink...
# Fetching competitor data for Curcumin C3...
# Fetching competitor data for Graviola...
# Fetching competitor data for Ecoensulin...

# %%
market_df = pd.DataFrame.from_dict(market_data, orient='index').reset_index()
market_df.rename(columns={"index":"keyword"}, inplace=True)

market_df.head()
# Out:
#            keyword  competitor_avg_price  sponsored_count  organic_count  \
# 0  Aloe vera juice                     0                0              0
# 1      Fruit drink                     0                0              0
# 2      Curcumin C3                     0                0              0
# 3         Graviola                     0                0              0
# 4       Ecoensulin                     0                0              0
#
#    competitor_avg_rating
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0

# %%
combined_df = df.merge(market_df, on="keyword", how="left")

# %%
combined_df["competition_intensity"] = combined_df["sponsored_count"] / (
    combined_df["sponsored_count"] + combined_df["organic_count"]
)

combined_df["price_gap"] = combined_df["bid"] - combined_df["competitor_avg_price"]

combined_df["market_pressure_score"] = combined_df["cpc_change_1d"].fillna(0) + combined_df["competition_intensity"]

combined_df.fillna(0, inplace=True)

# %%
combined_df.to_csv("final_2000_combined_dataset.csv", index=False)

print("Final combined dataset (~2000 rows) ready for anomaly detection!")
# Out:
# Final combined dataset (~2000 rows) ready for anomaly detection!

# %%
combined_df
# Out:
#                            date          keyword  impressions  clicks  \
# 0    2025-01-28 18:53:56.370265  Aloe vera juice         4550     290
# 1    2025-01-29 18:53:56.370265  Aloe vera juice         4039     115
# 2    2025-01-30 18:53:56.370265  Aloe vera juice         3916     121
# 3    2025-01-31 18:53:56.370265  Aloe vera juice         4102      93
# 4    2025-02-01 18:53:56.370265  Aloe vera juice         4595     220
# ...                         ...              ...          ...     ...
# 1995 2026-02-27 18:53:56.370265         Graviola         3276     139
# 1996 2026-02-28 18:53:56.370265         Graviola         3202     236
# 1997 2026-03-01 18:53:56.370265         Graviola         3600     179
# 1998 2026-03-02 18:53:56.370265         Graviola         3486     110
# 1999 2026-03-03 18:53:56.370265         Graviola         3449     268
#
#             spend         sales  orders       ctr        cpc       cvr  ...  \
# 0     3186.109604  14363.895886      38  0.063920  10.986585  0.131204  ...
# 1     1323.521744   7931.992634      12  0.028572  11.508885  0.111282  ...
# 2      973.133114  12383.340224      24  0.031004   8.042422  0.204951  ...
# 3     1370.592633   4488.941824      13  0.022800  14.737555  0.146554  ...
# 4     2991.868895  26787.730925      51  0.048006  13.599404  0.236062  ...
# ...           ...           ...     ...       ...        ...       ...  ...
# 1995  1938.192476   8945.080312      14  0.042731  13.943831  0.101972  ...
# 1996  3074.314918  20651.524070      30  0.073739  13.026758  0.127905  ...
# 1997   926.993620  11366.161990      29  0.049733   5.178735  0.166945  ...
# 1998   779.222047  18890.701898      25  0.031622   7.083837  0.232261  ...
# 1999  1404.776544  27223.148646      43  0.077772   5.241704  0.161269  ...
#
#       cvr_change_1d  acos_change_1d  cpc_change_1d  competitor_avg_price  \
# 0          0.000000        0.000000       0.000000                     0
# 1         -0.151836       -0.247753       0.047540                     0
# 2          0.841724       -0.529038      -0.301199                     0
# 3         -0.284931        2.885348       0.832477                     0
# 4          0.610745       -0.634201      -0.077228                     0
# ...             ...             ...            ...                   ...
# 1995      -0.654679        2.410438      -0.004697                     0
# 1996       0.254317       -0.312958      -0.065769                     0
# 1997       0.305219       -0.452144      -0.602454                     0
# 1998       0.391245       -0.494233       0.367870                     0
# 1999      -0.305656        0.250996      -0.260047                     0
#
#       sponsored_count  organic_count  competitor_avg_rating  \
# 0                   0              0                      0
# 1                   0              0                      0
# 2                   0              0                      0
# 3                   0              0                      0
# 4                   0              0                      0
# ...               ...            ...                    ...
# 1995                0              0                      0
# 1996                0              0                      0
# 1997                0              0                      0
# 1998                0              0                      0
# 1999                0              0                      0
#
#       competition_intensity  price_gap  market_pressure_score
# 0                       0.0  10.079369                    0.0
# 1                       0.0  13.598505                    0.0
# 2                       0.0   7.940837                    0.0
# 3                       0.0  15.997849                    0.0
# 4                       0.0  12.293582                    0.0
# ...                     ...        ...                    ...
# 1995                    0.0  14.545479                    0.0
# 1996                    0.0  14.169908                    0.0
# 1997                    0.0   5.717546                    0.0
# 1998                    0.0   7.233497                    0.0
# 1999                    0.0   6.118416                    0.0
#
# [2000 rows x 32 columns]

# %%
combined_df.columns
# Out:
# Index(['date', 'keyword', 'impressions', 'clicks', 'spend', 'sales', 'orders',
#        'ctr', 'cpc', 'cvr', 'acos', 'roas', 'bid', 'inventory_level',
#        'stock_out_flag', 'organic_rank', 'impressions_change_1d',
#        'clicks_change_1d', 'spend_change_1d', 'sales_change_1d',
#        'orders_change_1d', 'ctr_change_1d', 'cvr_change_1d', 'acos_change_1d',
#        'cpc_change_1d', 'competitor_avg_price', 'sponsored_count',
#        'organic_count', 'competitor_avg_rating', 'competition_intensity',
#        'price_gap', 'market_pressure_score'],
#       dtype='object')

# %%
combined_df.isnull().sum()
# Out:
# date                     0
# keyword                  0
# impressions              0
# clicks                   0
# spend                    0
# sales                    0
# orders                   0
# ctr                      0
# cpc                      0
# cvr                      0
# acos                     0
# roas                     0
# bid                      0
# inventory_level          0
# stock_out_flag           0
# organic_rank             0
# impressions_change_1d    0
# clicks_change_1d         0
# spend_change_1d          0
# sales_change_1d          0
# orders_change_1d         0
# ctr_change_1d            0
# cvr_change_1d            0
# acos_change_1d           0
# cpc_change_1d            0
# competitor_avg_price     0
# sponsored_count          0
# organic_count            0
# competitor_avg_rating    0
# competition_intensity    0
# price_gap                0
# market_pressure_score    0
# dtype: int64

# %%
# combined_df = pd.set_option("display.max_rows",None)

# %%
combined_df.describe()
# Out:
#                                 date  impressions       clicks        spend  \
# count                           2000  2000.000000  2000.000000  2000.000000
# mean   2025-08-16 06:53:56.370264576  4437.076500   219.451000  2182.107069
# min       2025-01-28 18:53:56.370265  2221.000000    47.000000   258.409702
# 25%    2025-05-08 12:53:56.370265088  3024.250000   138.000000  1238.894012
# 50%    2025-08-16 06:53:56.370265088  4720.000000   196.000000  1921.836090
# 75%    2025-11-24 00:53:56.370265088  5592.000000   292.000000  2845.376404
# max       2026-03-03 18:53:56.370265  7411.000000   549.000000  7402.643873
# std                              NaN  1381.392935   104.898372  1241.125369
#
#                sales       orders          ctr          cpc          cvr  \
# count    2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    23675.229016    43.365000     0.049584     9.962105     0.199795
# min      1735.424246     5.000000     0.020057     5.001186     0.100006
# 25%     12191.149796    24.000000     0.034522     7.471448     0.150317
# 50%     19403.802343    37.000000     0.049574     9.918623     0.199163
# 75%     31091.745885    57.000000     0.064600    12.485995     0.249235
# max    118535.198031   164.000000     0.079970    14.993535     0.299780
# std     15713.870791    25.322784     0.017188     2.879314     0.057375
#
#               acos  ...  cvr_change_1d  acos_change_1d  cpc_change_1d  \
# count  2000.000000  ...    2000.000000     2000.000000    2000.000000
# mean      0.110436  ...       0.094450        0.280149       0.093417
# min       0.026165  ...      -0.659830       -0.917811      -0.661099
# 25%       0.066809  ...      -0.254675       -0.374565      -0.265419
# 50%       0.095085  ...      -0.007335        0.013005       0.007399
# 75%       0.138772  ...       0.325835        0.634225       0.346380
# max       0.415939  ...       1.888464        7.705873       1.818885
# std       0.060894  ...       0.478242        0.973110       0.471869
#
#        competitor_avg_price  sponsored_count  organic_count  \
# count                2000.0           2000.0         2000.0
# mean                    0.0              0.0            0.0
# min                     0.0              0.0            0.0
# 25%                     0.0              0.0            0.0
# 50%                     0.0              0.0            0.0
# 75%                     0.0              0.0            0.0
# max                     0.0              0.0            0.0
# std                     0.0              0.0            0.0
#
#        competitor_avg_rating  competition_intensity    price_gap  \
# count                 2000.0                 2000.0  2000.000000
# mean                     0.0                    0.0    10.445058
# min                      0.0                    0.0     4.676514
# 25%                      0.0                    0.0     7.755858
# 50%                      0.0                    0.0    10.349037
# 75%                      0.0                    0.0    12.987913
# max                      0.0                    0.0    17.624647
# std                      0.0                    0.0     3.158571
#
#        market_pressure_score
# count                 2000.0
# mean                     0.0
# min                      0.0
# 25%                      0.0
# 50%                      0.0
# 75%                      0.0
# max                      0.0
# std                      0.0
#
# [8 rows x 31 columns]

# %%
combined_df.describe(include='O')
# Out:
#                 keyword
# count              2000
# unique                5
# top     Aloe vera juice
# freq                400

# %%
combined_df.columns
# Out:
# Index(['date', 'keyword', 'impressions', 'clicks', 'spend', 'sales', 'orders',
#        'ctr', 'cpc', 'cvr', 'acos', 'roas', 'bid', 'inventory_level',
#        'stock_out_flag', 'organic_rank', 'impressions_change_1d',
#        'clicks_change_1d', 'spend_change_1d', 'sales_change_1d',
#        'orders_change_1d', 'ctr_change_1d', 'cvr_change_1d', 'acos_change_1d',
#        'cpc_change_1d', 'competitor_avg_price', 'sponsored_count',
#        'organic_count', 'competitor_avg_rating', 'competition_intensity',
#        'price_gap', 'market_pressure_score'],
#       dtype='object')

# %%
# from sklearn.ensemble import IsolationForest
# from sklearn.preprocessing import StandardScaler

# def detect_business_anomalies(combined_df):
    
#     features = [
#         'acos', 'cvr', 'cpc', 'sales_change_1d', 
#         'price_gap', 'market_pressure_score', 'organic_rank', 'inventory_level'
#     ]
    
#     df_model = df[features].fillna(0)
    
#     scaler = StandardScaler()
#     X_scaled = scaler.fit_transform(df_model)
    
  
#     model = IsolationForest(contamination=0.05, random_state=42)
#     df['anomaly_signal'] = model.fit_predict(X_scaled)
    
#     # anomaly_signal: -1 (Anomaly), 1 (Normal)
#     anomalies = df[df['anomaly_signal'] == -1].copy()
    
#     return anomalies

# # 5. Alert Logic: 
# def generate_client_alerts(anomaly_row):
#     alerts = []
    
#     # Scenario 1: High ACOS 
#     if anomaly_row['acos'] > 50: 
#         alerts.append(f"⚠️ High ACOS Alert: Current ACOS is {anomaly_row['acos']}%. Ad efficiency is dropping.")
        
#     # Scenario 2: Competitor Attack (Price Gap)
#     if anomaly_row['price_gap'] > 5:
#         alerts.append(f"🚨 Competitor Pressure: Competitors are priced significantly lower (Gap: ${anomaly_row['price_gap']}).")
        
#     # Scenario 3: Inventory Risk
#     if anomaly_row['inventory_level'] < 10:
#         alerts.append(f"📦 Stock Alert: Low inventory ({anomaly_row['inventory_level']}). Immediate restock needed.")

#     # Scenario 4: Ranking Drop
#     if anomaly_row['organic_rank'] > 20:
#         alerts.append(f"📉 Ranking Alert: Your organic rank has slipped to {anomaly_row['organic_rank']}.")

#     return " | ".join(alerts)


# # Anomalies detect 
# detected_anomalies = detect_business_anomalies(combined_df)

# if not detected_anomalies.empty:
#     print(f"Total {len(detected_anomalies)} Unusual Activities Found!\n")
    
#     for index, row in detected_anomalies.iterrows():
#         reason = generate_client_alerts(row)
#         print(f"Date: {row['date']} | Keyword: {row['keyword']}")
#         print(f"Alert: {reason if reason else 'General pattern anomaly detected.'}")
#         print("-" * 50)
# else:
#     print("Everything looks normal. No alerts for the client.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 49
#      45     return " | ".join(alerts)
#      48 # Anomalies detect
# ---> 49 detected_anomalies = detect_business_anomalies(combined_df)
#      51 if not detected_anomalies.empty:
#      52     print(f"Total {len(detected_anomalies)} Unusual Activities Found!\n")
#
# Cell In[21], line 11, in detect_business_anomalies(combined_df)
#       4 def detect_business_anomalies(combined_df):
#       6     features = [
#       7         'acos', 'cvr', 'cpc', 'sales_change_1d',
#       8         'price_gap', 'market_pressure_score', 'organic_rank', 'inventory_level'
#       9     ]
# ---> 11     df_model = df[features].fillna(0)
#      13     scaler = StandardScaler()
#      14     X_scaled = scaler.fit_transform(df_model)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['price_gap', 'market_pressure_score'] not in index"

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler

def detect_business_anomalies(df):
    
    df.columns = df.columns.str.strip()
    
    
    desired_features = [
        'acos', 'cvr', 'cpc', 'sales_change_1d', 
        'price_gap', 'market_pressure_score', 'organic_rank', 'inventory_level'
    ]
    
    
    available_features = [f for f in desired_features if f in df.columns]
    missing_features = [f for f in desired_features if f not in df.columns]
    
    if missing_features:
        print(f"⚠️ Warning: Missing columns {missing_features}. Model will use: {available_features}")
    
    if not available_features:
        raise ValueError("Koi bhi zaruri feature dataframe mein nahi mila!")

    
    df_model = df[available_features].fillna(0)
    
    # Scaling
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(df_model)
    
    # Isolation Forest
    model = IsolationForest(contamination=0.05, random_state=42)
    df['anomaly_signal'] = model.fit_predict(X_scaled)
    
    return df[df['anomaly_signal'] == -1].copy()


try:
    detected_anomalies = detect_business_anomalies(combined_df)
    print(f"Success! Found {len(detected_anomalies)} anomalies.")
except Exception as e:
    print(f"Abhi bhi error hai: {e}")
# Out:
# Success! Found 100 anomalies.

# %%
anomalies_only = detected_anomalies[['date', 'keyword', 'acos', 'sales_change_1d', 'price_gap', 'organic_rank']]
print(anomalies_only.head(50))
# Out:
#                           date          keyword      acos  sales_change_1d  \
# 0   2025-01-28 18:53:56.370265  Aloe vera juice  0.221814         0.000000
# 1   2025-01-29 18:53:56.370265  Aloe vera juice  0.166859        -0.447783
# 3   2025-01-31 18:53:56.370265  Aloe vera juice  0.305326        -0.637502
# 4   2025-02-01 18:53:56.370265  Aloe vera juice  0.111688         4.967493
# 20  2025-02-17 18:53:56.370265  Aloe vera juice  0.037558         4.651289
# 28  2025-02-25 18:53:56.370265  Aloe vera juice  0.094478         3.336565
# 50  2025-03-19 18:53:56.370265  Aloe vera juice  0.371579        -0.457025
# 63  2025-04-01 18:53:56.370265  Aloe vera juice  0.151480         0.174156
# 80  2025-04-18 18:53:56.370265  Aloe vera juice  0.126721         2.025319
# 191 2025-08-07 18:53:56.370265  Aloe vera juice  0.213755        -0.836226
# 200 2025-08-16 18:53:56.370265  Aloe vera juice  0.341018        -0.778995
# 201 2025-08-17 18:53:56.370265  Aloe vera juice  0.055789         9.499724
# 213 2025-08-29 18:53:56.370265  Aloe vera juice  0.170730        -0.348405
# 269 2025-10-24 18:53:56.370265  Aloe vera juice  0.334525        -0.592207
# 270 2025-10-25 18:53:56.370265  Aloe vera juice  0.041248        11.240072
# 313 2025-12-07 18:53:56.370265  Aloe vera juice  0.044452         6.106029
# 326 2025-12-20 18:53:56.370265  Aloe vera juice  0.062280         6.244778
# 335 2025-12-29 18:53:56.370265  Aloe vera juice  0.097697         4.461950
# 344 2026-01-07 18:53:56.370265  Aloe vera juice  0.340488        -0.827551
# 348 2026-01-11 18:53:56.370265  Aloe vera juice  0.049323         5.734800
# 376 2026-02-08 18:53:56.370265  Aloe vera juice  0.293654        -0.570881
# 381 2026-02-13 18:53:56.370265  Aloe vera juice  0.330457        -0.660803
# 420 2025-02-17 18:53:56.370265      Curcumin C3  0.317665        -0.866970
# 421 2025-02-18 18:53:56.370265      Curcumin C3  0.055936         5.032236
# 439 2025-03-08 18:53:56.370265      Curcumin C3  0.150870         0.111864
# 445 2025-03-14 18:53:56.370265      Curcumin C3  0.054526         8.567238
# 449 2025-03-18 18:53:56.370265      Curcumin C3  0.408281        -0.233849
# 450 2025-03-19 18:53:56.370265      Curcumin C3  0.033556         7.169740
# 469 2025-04-07 18:53:56.370265      Curcumin C3  0.205607        -0.658358
# 471 2025-04-09 18:53:56.370265      Curcumin C3  0.315561         0.998699
# 472 2025-04-10 18:53:56.370265      Curcumin C3  0.248398         0.071093
# 487 2025-04-25 18:53:56.370265      Curcumin C3  0.053991         4.203405
# 497 2025-05-05 18:53:56.370265      Curcumin C3  0.329895        -0.646594
# 502 2025-05-10 18:53:56.370265      Curcumin C3  0.369928        -0.660980
# 535 2025-06-12 18:53:56.370265      Curcumin C3  0.039706         5.991783
# 543 2025-06-20 18:53:56.370265      Curcumin C3  0.263525         0.398810
# 610 2025-08-26 18:53:56.370265      Curcumin C3  0.071277        -0.767466
# 618 2025-09-03 18:53:56.370265      Curcumin C3  0.286912        -0.221140
# 628 2025-09-13 18:53:56.370265      Curcumin C3  0.066659         3.242301
# 656 2025-10-11 18:53:56.370265      Curcumin C3  0.248669        -0.792149
# 722 2025-12-16 18:53:56.370265      Curcumin C3  0.069854         5.148330
# 732 2025-12-26 18:53:56.370265      Curcumin C3  0.407234        -0.565405
# 794 2026-02-26 18:53:56.370265      Curcumin C3  0.072643         3.186880
# 800 2025-01-28 18:53:56.370265       Ecoensulin  0.048507         0.000000
# 801 2025-01-29 18:53:56.370265       Ecoensulin  0.093846        -0.848892
# 805 2025-02-02 18:53:56.370265       Ecoensulin  0.083717         2.812649
# 821 2025-02-18 18:53:56.370265       Ecoensulin  0.293039        -0.592369
# 864 2025-04-02 18:53:56.370265       Ecoensulin  0.093251        13.185099
# 869 2025-04-07 18:53:56.370265       Ecoensulin  0.111318         4.030565
# 873 2025-04-11 18:53:56.370265       Ecoensulin  0.415939        -0.614673
#
#      price_gap  organic_rank
# 0    10.079369            88
# 1    13.598505             2
# 3    15.997849            55
# 4    12.293582            89
# 20    8.425006             2
# 28   14.018379            99
# 50   16.703812            85
# 63   16.527954            93
# 80   14.955684             1
# 191  16.136930            20
# 200  11.534428            76
# 201  10.263705            20
# 213  17.624647            50
# 269  10.991094             5
# 270  11.376895            28
# 313   8.461980            74
# 326   7.947088             4
# 335  15.790260            55
# 344   9.817252            43
# 348   9.860633            33
# 376  16.834651            81
# 381  13.381066            60
# 420  14.596243             7
# 421   6.650885            96
# 439  16.905210            82
# 445  10.439883            62
# 449  14.366268            14
# 450   8.093221            49
# 469   7.751776             6
# 471  14.696602            58
# 472  16.475730            92
# 487  11.035179            88
# 497  13.537120            18
# 502  12.972415            58
# 535   7.970717            78
# 543  15.440327             3
# 610   5.822114             1
# 618  17.182396             9
# 628  14.617748             2
# 656   9.947647             3
# 722  12.090744            43
# 732  16.193700            62
# 794   5.859531            27
# 800   9.509797            89
# 801   6.214137            17
# 805  17.136196             7
# 821  13.145833            85
# 864  15.014227            34
# 869  13.230204            83
# 873  15.016822            31
